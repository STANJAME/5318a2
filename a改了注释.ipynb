# %% [markdown]
# # 1. Preprocessing
# ## Import data

# %%
! pip install scikeras
! pip install pandas
! pip install nltk
! pip install scikit-learn
# Out:
# pyenv: pip: command not found
#
# The `pip' command exists in these Python versions:
#   3.10.13
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.
# pyenv: pip: command not found
#
# The `pip' command exists in these Python versions:
#   3.10.13
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.
# pyenv: pip: command not found
#
# The `pip' command exists in these Python versions:
#   3.10.13
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.
# pyenv: pip: command not found
#
# The `pip' command exists in these Python versions:
#   3.10.13
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.

# %%
import pandas as pd
df = pd.read_csv('training.300000.processed.noemoticon.csv', encoding='ISO-8859-1')

# %% [markdown]
# ## Text clean

# %%
import nltk
nltk.download("stopwords")
nltk.download("punkt")
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/liuyifan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/liuyifan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/liuyifan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))


def clean_text(text):
    # transfer to lower characters
    text = text.lower()
    
    # eliminate url link
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    
    # eliminate special character
    text = re.sub(r'@\w+|#\w+', '', text)
    
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # eliminate stop word
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    
   
    return ' '.join(tokens)

# apply clean function to data frame
df['cleaned_text'] = df['text'].apply(clean_text)

df[['text', 'cleaned_text']].head()
# Out:
#                                                 text  \
# 0             @chrishasboobs AHHH I HOPE YOUR OK!!!
# 1  @misstoriblack cool , i have no tweet apps  fo...
# 2  @TiannaChaos i know  just family drama. its la...
# 3  School email won't open  and I have geography ...
# 4                             upper airways problem
#
#                                         cleaned_text
# 0                                       ahhh hope ok
# 1                               cool tweet apps razr
# 2  know family drama lamehey next time u hang kim...
# 3  school email wont open geography stuff revise ...
# 4                              upper airways problem

# %% [markdown]
# ## Divide dataset into two parts, trainset and testset

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Transfer original labels to 0-1 label
y = df['sentiment'].values  
y = (y == 4).astype(int) 
X_train, X_test, y_train, y_test = train_test_split(df['cleaned_text'], y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Tokenization, Padding

# %%
# Define tokenizer
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

# Transfer to sequences
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# Padding sequence to a constant length
X_train = pad_sequences(X_train, maxlen=50)
X_test = pad_sequences(X_test, maxlen=50)

# %% [markdown]
# # 2. Deep learning

# %% [markdown]
# ## CNN
# Model implement

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Embedding, Dropout, Flatten, Input

# from previous block, which maximum length of sequence is 50
sequence_length = 50

# define cnn
model_1 = Sequential()

# add input layer
model_1.add(Input(shape=(sequence_length,)))

# add embedding layer, map word id to a vector
model_1.add(Embedding(input_dim=10000, output_dim=50))

# convolutional layer
model_1.add(Conv1D(filters=128, kernel_size=5, activation='relu'))

# pool layer
model_1.add(MaxPooling1D(pool_size=2))

# fc1
model_1.add(Flatten())

# Dropout layer
model_1.add(Dropout(0.5))

# fc2
model_1.add(Dense(64, activation='relu'))

# output layer
model_1.add(Dense(1, activation='sigmoid'))

model_1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# show model structure
model_1.summary()

model_1.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
loss, accuracy = model_1.evaluate(X_test, y_test)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 50, 50)         │       500,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 46, 128)        │        32,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 23, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2944)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2944)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │       188,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 720,673 (2.75 MB)
#  Trainable params: 720,673 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.7060 - loss: 0.5474 - val_accuracy: 0.7718 - val_loss: 0.4763
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.7958 - loss: 0.4403 - val_accuracy: 0.7738 - val_loss: 0.4700
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8185 - loss: 0.3988 - val_accuracy: 0.7690 - val_loss: 0.4946
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.8436 - loss: 0.3524 - val_accuracy: 0.7617 - val_loss: 0.5284
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8652 - loss: 0.3078 - val_accuracy: 0.7559 - val_loss: 0.5800
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.8807 - loss: 0.2745 - val_accuracy: 0.7498 - val_loss: 0.6678
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8919 - loss: 0.2496 - val_accuracy: 0.7477 - val_loss: 0.7484
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9004 - loss: 0.2317 - val_accuracy: 0.7449 - val_loss: 0.7999
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.9094 - loss: 0.2115 - val_accuracy: 0.7415 - val_loss: 0.8646
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9150 - loss: 0.1998 - val_accuracy: 0.7418 - val_loss: 0.9413
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7430 - loss: 0.9191

# %% [markdown]
# Fine tune

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Embedding, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
import json


# Define cnn model structure
def create_model(optimizer='adam', filters=64, kernel_size=5, dropout_rate=0.5):
    sequence_length = 50  
    model = Sequential()
    model.add(Input(shape=(sequence_length,)))
    model.add(Embedding(input_dim=10000, output_dim=50))
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model
# Wrape Keras model for sklearn
model_1_f = KerasClassifier(build_fn=create_model, epochs=10, batch_size=128, verbose=0)

# Search list
param_dist = {
    'model__optimizer': ['adam', 'rmsprop'],
    'model__filters': [32, 64, 128],
    'model__kernel_size': [3, 5],
    'model__dropout_rate': [0.2, 0.3],
    'epochs': [5, 10, 15],
    'batch_size': [32, 64]
}

random_search = RandomizedSearchCV(estimator=model_1_f, param_distributions=param_dist, n_iter=10, cv=3)
random_search.fit(X_train,y_train)
# save best paramaters combination
best_params = random_search.best_params_
with open('best_paramscnn.json', 'w') as f:
    json.dump(best_params, f)
#    
model_1_best=random_search.best_estimator_.model_
model_1_best.save("bestcnn.h5")
# Out:
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/liu/miniconda3/envs/tensorflow/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# RandomizedSearchCV(cv=3,
#                    estimator=KerasClassifier(batch_size=128, build_fn=<function create_model at 0x7fce7c740e00>, epochs=10, verbose=0),
#                    param_distributions={'batch_size': [32, 64],
#                                         'epochs': [5, 10, 15],
#                                         'model__dropout_rate': [0.2, 0.3],
#                                         'model__filters': [32, 64, 128],
#                                         'model__kernel_size': [3, 5],
#                                         'model__optimizer': ['adam',
#                                                              'rmsprop']})

# %%
import json
from sklearn.metrics import accuracy_score

# get best parameters combination
best_params = random_search.best_params_

# save each parameters in a json file
with open('best_paramscnn.json', 'w') as f:
    json.dump(best_params, f)

# %% [markdown]
# ## LSTM
# model implement

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input
from tensorflow.keras.optimizers import Adam
def create_lstm_model(optimizer='adam',output_dim=50 ,units=64,dropout_rate=0.5):
    model=Sequential()
    sequence_length=50
    model.add(Input(shape=(sequence_length,)))
    model.add(Embedding(input_dim=10000, output_dim=output_dim))
    model.add(LSTM(units=units))
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

model_2=create_lstm_model()
model_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_2.summary()
model_2.fit(X_train,y_train,epochs=10, batch_size=128, validation_split=0.2)
loss, accuracy=model_2.evaluate(X_test,y_test)
# Out:
# 2024-10-09 18:47:00.115403: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 18:47:00.115444: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 18:47:00.115451: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 18:47:00.115471: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 18:47:00.115487: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 50, 50)         │       500,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 533,665 (2.04 MB)
#  Trainable params: 533,665 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 2024-10-09 18:47:00.666863: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.7189 - loss: 0.5416 - val_accuracy: 0.7716 - val_loss: 0.4801
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.7902 - loss: 0.4475 - val_accuracy: 0.7725 - val_loss: 0.4726
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.8021 - loss: 0.4236 - val_accuracy: 0.7729 - val_loss: 0.4780
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.8125 - loss: 0.4034 - val_accuracy: 0.7688 - val_loss: 0.4893
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.8230 - loss: 0.3846 - val_accuracy: 0.7674 - val_loss: 0.5079
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.8354 - loss: 0.3608 - val_accuracy: 0.7660 - val_loss: 0.5312
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.8457 - loss: 0.3388 - val_accuracy: 0.7597 - val_loss: 0.5736
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.8561 - loss: 0.3201 - val_accuracy: 0.7575 - val_loss: 0.6207
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.8641 - loss: 0.2996 - val_accuracy: 0.7538 - val_loss: 0.7031
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.8707 - loss: 0.2827 - val_accuracy: 0.7475 - val_loss: 0.7371
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7496 - loss: 0.7259

# %% [markdown]
# Fine Tune

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.optimizers import Adam
import json

def create_lstm_model(optimizer='adam',output_dim=50 ,units=64,dropout_rate=0.5):
    model=Sequential()
    sequence_length=50
    model.add(Input(shape=(sequence_length,)))
    model.add(Embedding(input_dim=10000, output_dim=output_dim))
    model.add(LSTM(units=units))
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model
# Wrape Keras model for sklearn
model_2_f = KerasClassifier(build_fn=create_lstm_model, epochs=10, batch_size=128, verbose=0)
# Search list
param_dist = {
    'model__optimizer': ['adam', 'rmsprop'],
    'model__output_dim': [50, 100, 150,200],
    'model__units': [64, 128],
    'model__dropout_rate': [0.2, 0.3,0.5],
    'epochs': [5, 10, 15],
    'batch_size': [32, 64]
}
random_search = RandomizedSearchCV(estimator=model_2_f, param_distributions=param_dist, n_iter=10, cv=3, n_jobs=2)
random_search.fit(X_train,y_train)

# save best paramaters combination
best_params = random_search.best_params_
with open('best_paramlstm.json', 'w') as f:
    json.dump(best_params, f)
#    
model_2_best=random_search.best_estimator_.model_
model_2_best.save("bestlstm.h5")
# Out:
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 19:22:59.306833: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 19:22:59.306833: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 19:22:59.306856: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 19:22:59.306856: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 19:22:59.306862: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 19:22:59.306862: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 19:22:59.306874: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 19:22:59.306874: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 19:22:59.306884: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-10-09 19:22:59.306885: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-10-09 19:22:59.736368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2024-10-09 19:22:59.739540: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 19:34:37.210367: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 2024-10-09 19:34:37.210387: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
# 2024-10-09 19:34:37.210430: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3640505365015539777
# 2024-10-09 19:34:37.210469: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16855655062413599275
# 2024-10-09 19:34:37.210483: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1542480363492270697
# 2024-10-09 19:34:37.210503: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6796418713199002820
# 2024-10-09 19:34:37.210521: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11137629003135207032
# 2024-10-09 19:34:37.210530: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18323502198425601938
# 2024-10-09 19:34:37.210540: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10924455287625197308
# 2024-10-09 19:34:37.210548: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4970374989256899150
# 2024-10-09 19:34:37.210566: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15594412742007696298
# 2024-10-09 19:34:37.210588: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1568450132833922302
# 2024-10-09 19:34:37.210598: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11786257913192647424
# 2024-10-09 19:34:37.210606: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14525565520840036218
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 19:34:38.118990: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
# 2024-10-09 19:34:38.119012: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3640505365015539777
# 2024-10-09 19:34:38.119017: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16855655062413599275
# 2024-10-09 19:34:38.119024: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1542480363492270697
# 2024-10-09 19:34:38.119033: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6796418713199002820
# 2024-10-09 19:34:38.119037: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11137629003135207032
# 2024-10-09 19:34:38.119042: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18323502198425601938
# 2024-10-09 19:34:38.119046: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10924455287625197308
# 2024-10-09 19:34:38.119050: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4970374989256899150
# 2024-10-09 19:34:38.119054: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15594412742007696298
# 2024-10-09 19:34:38.119063: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1568450132833922302
# 2024-10-09 19:34:38.119068: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11786257913192647424
# 2024-10-09 19:34:38.119071: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14525565520840036218
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 19:34:39.038387: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3640505365015539777
# 2024-10-09 19:34:39.038409: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16855655062413599275
# 2024-10-09 19:34:39.038414: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1542480363492270697
# 2024-10-09 19:34:39.038421: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6796418713199002820
# 2024-10-09 19:34:39.038425: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11137629003135207032
# 2024-10-09 19:34:39.038428: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18323502198425601938
# 2024-10-09 19:34:39.038433: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10924455287625197308
# 2024-10-09 19:34:39.038437: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4970374989256899150
# 2024-10-09 19:34:39.038441: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15594412742007696298
# 2024-10-09 19:34:39.038448: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1568450132833922302
# 2024-10-09 19:34:39.038452: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11786257913192647424
# 2024-10-09 19:34:39.038455: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14525565520840036218
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:24:25.105978: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 20:24:25.106007: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 20:24:25.106012: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 20:24:25.106027: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 20:24:25.106040: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-10-09 20:24:25.536258: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2024-10-09 20:24:26.297370: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 2024-10-09 20:24:26.297391: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/cond/else/_63/rmsprop/cond/cond/ScatterNd/shape/_84]]
# 2024-10-09 20:24:26.297419: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 953607518815548137
# 2024-10-09 20:24:26.297423: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5561021098010541747
# 2024-10-09 20:24:26.297428: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6916661057127487027
# 2024-10-09 20:24:26.297432: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14003127431525210361
# 2024-10-09 20:24:26.297436: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12882437811422334475
# 2024-10-09 20:24:26.297444: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5898393188645621890
# 2024-10-09 20:24:26.297447: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14868456337489760934
# 2024-10-09 20:24:26.297451: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3362976125243487434
# 2024-10-09 20:24:26.297455: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9056975852505577140
# 2024-10-09 20:24:26.297459: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1269013871415691376
# 2024-10-09 20:24:26.297463: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15471826374048229904
# 2024-10-09 20:24:26.297466: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9653028572349738174
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:24:27.466714: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/cond/else/_63/rmsprop/cond/cond/ScatterNd/shape/_84]]
# 2024-10-09 20:24:27.466739: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 953607518815548137
# 2024-10-09 20:24:27.466745: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5561021098010541747
# 2024-10-09 20:24:27.466751: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6916661057127487027
# 2024-10-09 20:24:27.466756: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14003127431525210361
# 2024-10-09 20:24:27.466763: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12882437811422334475
# 2024-10-09 20:24:27.466773: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5898393188645621890
# 2024-10-09 20:24:27.466776: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14868456337489760934
# 2024-10-09 20:24:27.466781: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3362976125243487434
# 2024-10-09 20:24:27.466786: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9056975852505577140
# 2024-10-09 20:24:27.466790: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1269013871415691376
# 2024-10-09 20:24:27.466794: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15471826374048229904
# 2024-10-09 20:24:27.466798: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9653028572349738174
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:24:28.444573: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 953607518815548137
# 2024-10-09 20:24:28.444595: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5561021098010541747
# 2024-10-09 20:24:28.444601: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6916661057127487027
# 2024-10-09 20:24:28.444606: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14003127431525210361
# 2024-10-09 20:24:28.444612: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12882437811422334475
# 2024-10-09 20:24:28.444619: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5898393188645621890
# 2024-10-09 20:24:28.444623: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14868456337489760934
# 2024-10-09 20:24:28.444629: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3362976125243487434
# 2024-10-09 20:24:28.444633: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9056975852505577140
# 2024-10-09 20:24:28.444636: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1269013871415691376
# 2024-10-09 20:24:28.444640: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15471826374048229904
# 2024-10-09 20:24:28.444644: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9653028572349738174
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:24:29.468877: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/cond/else/_63/rmsprop/cond/cond/ScatterNd/shape/_84]]
# 2024-10-09 20:24:29.468907: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5561021098010541747
# 2024-10-09 20:24:29.468913: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 953607518815548137
# 2024-10-09 20:24:29.468918: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6916661057127487027
# 2024-10-09 20:24:29.468925: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14003127431525210361
# 2024-10-09 20:24:29.468963: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12882437811422334475
# 2024-10-09 20:24:29.468992: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5898393188645621890
# 2024-10-09 20:24:29.468998: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14868456337489760934
# 2024-10-09 20:24:29.469002: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3362976125243487434
# 2024-10-09 20:24:29.469010: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9056975852505577140
# 2024-10-09 20:24:29.469014: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1269013871415691376
# 2024-10-09 20:24:29.469019: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15471826374048229904
# 2024-10-09 20:24:29.469023: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9653028572349738174
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:24:34.431589: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 20:24:34.431618: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 20:24:34.431624: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 20:24:34.431638: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 20:24:34.431649: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-10-09 20:24:34.856115: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2024-10-09 20:24:35.541545: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 2024-10-09 20:24:35.541565: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ExpandDims_1/_66]]
# 2024-10-09 20:24:35.541573: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9052812218086780697
# 2024-10-09 20:24:35.541578: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16836458198933624489
# 2024-10-09 20:24:35.541584: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14981998908752390165
# 2024-10-09 20:24:35.541589: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6890510156343126277
# 2024-10-09 20:24:35.541595: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18110536061377802197
# 2024-10-09 20:24:35.541607: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11363143763727893392
# 2024-10-09 20:24:35.541611: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 17844373202545890062
# 2024-10-09 20:24:35.541615: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 17720946726727378314
# 2024-10-09 20:24:35.541620: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 2227482321711671130
# 2024-10-09 20:24:35.541625: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5316658145202063780
# 2024-10-09 20:24:35.541631: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1843327173713865664
# 2024-10-09 20:24:35.541636: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15206861603841949476
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:24:36.660533: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ExpandDims_1/_66]]
# 2024-10-09 20:24:36.660555: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9052812218086780697
# 2024-10-09 20:24:36.660562: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16836458198933624489
# 2024-10-09 20:24:36.660568: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14981998908752390165
# 2024-10-09 20:24:36.660574: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6890510156343126277
# 2024-10-09 20:24:36.660580: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18110536061377802197
# 2024-10-09 20:24:36.660590: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11363143763727893392
# 2024-10-09 20:24:36.660595: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 17844373202545890062
# 2024-10-09 20:24:36.660602: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 17720946726727378314
# 2024-10-09 20:24:36.660607: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 2227482321711671130
# 2024-10-09 20:24:36.660612: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5316658145202063780
# 2024-10-09 20:24:36.660618: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1843327173713865664
# 2024-10-09 20:24:36.660626: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15206861603841949476
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:44:30.207831: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
# 2024-10-09 20:44:30.207853: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3640505365015539777
# 2024-10-09 20:44:30.207859: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16855655062413599275
# 2024-10-09 20:44:30.207866: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1542480363492270697
# 2024-10-09 20:44:30.207881: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6796418713199002820
# 2024-10-09 20:44:30.207885: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11137629003135207032
# 2024-10-09 20:44:30.207890: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18323502198425601938
# 2024-10-09 20:44:30.207896: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10924455287625197308
# 2024-10-09 20:44:30.207901: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4970374989256899150
# 2024-10-09 20:44:30.207912: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15594412742007696298
# 2024-10-09 20:44:30.207916: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1568450132833922302
# 2024-10-09 20:44:30.207922: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11786257913192647424
# 2024-10-09 20:44:30.207926: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14525565520840036218
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:44:31.103646: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3640505365015539777
# 2024-10-09 20:44:31.103668: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 16855655062413599275
# 2024-10-09 20:44:31.103731: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1542480363492270697
# 2024-10-09 20:44:31.103761: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6796418713199002820
# 2024-10-09 20:44:31.103772: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11137629003135207032
# 2024-10-09 20:44:31.103777: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18323502198425601938
# 2024-10-09 20:44:31.103783: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10924455287625197308
# 2024-10-09 20:44:31.103788: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4970374989256899150
# 2024-10-09 20:44:31.103794: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15594412742007696298
# 2024-10-09 20:44:31.103798: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1568450132833922302
# 2024-10-09 20:44:31.103804: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 11786257913192647424
# 2024-10-09 20:44:31.103808: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14525565520840036218
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 20:44:36.700959: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 20:44:36.700987: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 20:44:36.700993: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 20:44:36.701007: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 20:44:36.701020: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-10-09 20:44:37.117431: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2024-10-09 20:44:37.758186: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 2024-10-09 20:44:37.758210: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15172169576713580628
# 2024-10-09 20:44:37.758216: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INTERNAL: stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
# 2024-10-09 20:44:37.758221: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 330999183025074239
# 2024-10-09 20:44:37.758226: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4388956801075993955
# 2024-10-09 20:44:37.758231: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4596610211428075183
# 2024-10-09 20:44:37.758238: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14336575825535457363
# 2024-10-09 20:44:37.758243: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4836558564860595729
# 2024-10-09 20:44:37.758250: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 13666383933945083386
# 2024-10-09 20:44:37.758255: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12267914437051451630
# 2024-10-09 20:44:37.758260: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9281023419203717844
# 2024-10-09 20:44:37.758265: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 5501269836629879452
# 2024-10-09 20:44:37.758276: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 13297686391722790060
# 2024-10-09 20:44:37.758281: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1949753231785205036
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 2024-10-09 21:25:51.377821: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2024-10-09 21:25:51.377853: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-09 21:25:51.377858: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-09 21:25:51.377873: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-09 21:25:51.377886: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-10-09 21:25:51.897131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 12 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_71768]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_73622]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_75476]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
# ...
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/cond/else/_63/rmsprop/cond/cond/ScatterNd/shape/_84]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_5562]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/cond/else/_63/rmsprop/cond/cond/ScatterNd/shape/_84]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_7416]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ExpandDims_1/_66]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_1854]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ExpandDims_1/_66]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_3708]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_587402]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_589256]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# Detected at node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62 defined at (most recent call last):
# <stack traces unavailable>
# 2 root error(s) found.
#   (0) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 	 [[StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ones_1/packed/_64]]
#   (1) INTERNAL:  stream cannot wait for itself
# 	 [[{{node StatefulPartitionedCall/rmsprop/cond/then/_28/rmsprop/cond/ScatterNd/shape/_62}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_1854]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.76054583        nan 0.73809583 0.7598625         nan        nan
#  0.7359375         nan 0.73161667 0.76072917]
#   warnings.warn(
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Transformer

# %% [markdown]
# Implement

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Dense, Dropout, LayerNormalization, Embedding
import numpy as np

# Define attention
class MultiHeadAttention(Layer):
    def __init__(self, num_heads, d_model):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.depth = d_model // num_heads
        
        self.wq = Dense(d_model)
        self.wk = Dense(d_model)
        self.wv = Dense(d_model)
        
        self.dense = Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]
        
        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        # Scaled dot-product attention
        scaled_attention_logits = tf.matmul(q, k, transpose_b=True)
        scaled_attention_logits /= tf.math.sqrt(tf.cast(self.depth, tf.float32))

        if mask is not None:
            scaled_attention_logits += (mask * -1e9)

        attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
        output = tf.matmul(attention_weights, v)

        output = tf.transpose(output, perm=[0, 2, 1, 3])
        output = tf.reshape(output, (batch_size, -1, self.d_model))
        return self.dense(output)

# feedforward network
class FeedForward(Layer):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = Dense(d_ff, activation='relu')
        self.linear2 = Dense(d_model)

    def call(self, x):
        return self.linear2(self.linear1(x))

# Add & Norm layer
class AddNormalization(Layer):
    def __init__(self):
        super(AddNormalization, self).__init__()
        self.layer_norm = LayerNormalization(epsilon=1e-6)

    def call(self, x, sublayer_output):
        return self.layer_norm(x + sublayer_output)

# encoder
class EncoderLayer(Layer):
    def __init__(self, num_heads, d_model, d_ff, rate=0.1):
        super(EncoderLayer, self).__init__()
        self.mha = MultiHeadAttention(num_heads, d_model)
        self.ffn = FeedForward(d_model, d_ff)
        self.add_norm1 = AddNormalization()
        self.add_norm2 = AddNormalization()
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, x, training, mask):
        attn_output = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.add_norm1(x, attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.add_norm2(out1, ffn_output)
class Encoder(Layer):
    def __init__(self, num_layers, num_heads, d_model, d_ff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()
        self.d_model = d_model
        self.num_layers = num_layers
        self.embedding = Embedding(input_vocab_size, d_model)
        self.pos_encoding = self.positional_encoding(maximum_position_encoding, self.d_model)

        self.enc_layers = [EncoderLayer(num_heads, d_model, d_ff, rate) for _ in range(num_layers)]
        self.dropout = Dropout(rate)

    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(np.arange(position)[:, np.newaxis], np.arange(d_model)[np.newaxis, :], d_model)
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])  
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])  
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)

    def get_angles(self, pos, i, d_model):
        return pos / np.power(10000, (2 * (i // 2)) / np.float32(d_model))

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        return self.dropout(x, training=training)

class TransformerModel(tf.keras.Model):
    def __init__(self, num_layers, num_heads, d_model, d_ff, input_vocab_size, maximum_position_encoding):
        super(TransformerModel, self).__init__()
        self.encoder = Encoder(num_layers, num_heads, d_model, d_ff, input_vocab_size, maximum_position_encoding)
        self.pooling = tf.keras.layers.GlobalAveragePooling1D()  
        self.dense = Dense(2, activation='softmax')  

    def create_padding_mask(self, seq):
        mask = tf.cast(tf.equal(seq, 0), tf.float32)  
        return mask[:, tf.newaxis, tf.newaxis, :]  

    def call(self, x, training=False):
        mask = self.create_padding_mask(x)  
        x = self.encoder(x, training=training, mask=mask)  
        x = self.pooling(x)  
        return self.dense(x)
# Out:
# (64, 50, 128)
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(

# %%
num_layers = 2
num_heads = 4
d_model = 128
d_ff = 512
input_vocab_size = 10000
maximum_position_encoding = 50

model_3 = TransformerModel(num_layers, num_heads, d_model, d_ff, input_vocab_size, maximum_position_encoding)

# Compile model
model_3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_3.summary()
model_3.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.1)
# Out:
# Model: "transformer_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_1 (Encoder)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'encoder_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.6859 - loss: 0.5802 - val_accuracy: 0.6991 - val_loss: 0.5659
# Epoch 2/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7613 - loss: 0.4990 - val_accuracy: 0.7710 - val_loss: 0.4992
# Epoch 3/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - accuracy: 0.7711 - loss: 0.4845 - val_accuracy: 0.7592 - val_loss: 0.5051
# Epoch 4/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7744 - loss: 0.4808 - val_accuracy: 0.7693 - val_loss: 0.4998
# Epoch 5/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7777 - loss: 0.4756 - val_accuracy: 0.7694 - val_loss: 0.4990
# Epoch 6/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7793 - loss: 0.4721 - val_accuracy: 0.7560 - val_loss: 0.5085
# Epoch 7/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 37s 11ms/step - accuracy: 0.7820 - loss: 0.4704 - val_accuracy: 0.7590 - val_loss: 0.5073
# Epoch 8/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 37s 11ms/step - accuracy: 0.7807 - loss: 0.4715 - val_accuracy: 0.7560 - val_loss: 0.5118
# Epoch 9/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 36s 11ms/step - accuracy: 0.7845 - loss: 0.4670 - val_accuracy: 0.7480 - val_loss: 0.5246
# Epoch 10/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7853 - loss: 0.4663 - val_accuracy: 0.7525 - val_loss: 0.5136
# Epoch 11/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7851 - loss: 0.4672 - val_accuracy: 0.7685 - val_loss: 0.5036
# Epoch 12/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7834 - loss: 0.4671 - val_accuracy: 0.7686 - val_loss: 0.5025
# Epoch 13/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7861 - loss: 0.4652 - val_accuracy: 0.7685 - val_loss: 0.5010
# Epoch 14/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7856 - loss: 0.4656 - val_accuracy: 0.7673 - val_loss: 0.5040
# Epoch 15/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7876 - loss: 0.4643 - val_accuracy: 0.7665 - val_loss: 0.5078
# Epoch 16/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - accuracy: 0.7878 - loss: 0.4626 - val_accuracy: 0.7667 - val_loss: 0.5030
# Epoch 17/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7876 - loss: 0.4632 - val_accuracy: 0.7685 - val_loss: 0.5051
# Epoch 18/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7882 - loss: 0.4628 - val_accuracy: 0.7661 - val_loss: 0.5040
# Epoch 19/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7886 - loss: 0.4612 - val_accuracy: 0.7539 - val_loss: 0.5199
# Epoch 20/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.7880 - loss: 0.4616 - val_accuracy: 0.7675 - val_loss: 0.5093

# %%
loss, accuracy = model_3.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7675 - loss: 0.4978
# Test Accuracy: 0.7657

# %% [markdown]
# Fine tune

# %%
def create_model(num_layers=2, num_heads=4, d_model=128, d_ff=512):
    model = TransformerModel(num_layers, num_heads, d_model, d_ff, input_vocab_size, maximum_position_encoding)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

from sklearn.base import BaseEstimator, ClassifierMixin

class KerasClassifierWrapper(BaseEstimator, ClassifierMixin):
    def __init__(self, num_layers=2, num_heads=4, d_model=128, d_ff=512, epochs=10, batch_size=64):
        self.num_layers = num_layers
        self.num_heads = num_heads
        self.d_model = d_model
        self.d_ff = d_ff
        self.epochs = epochs
        self.batch_size = batch_size
        self.model = None

    def fit(self, X, y):
        self.model = create_model(self.num_layers, self.num_heads, self.d_model, self.d_ff)
        self.model.fit(X, y, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        return self

    def predict(self, X):
        return np.argmax(self.model.predict(X), axis=-1)

    def score(self, X, y):
        return self.model.evaluate(X, y, verbose=0)[1]  # Return accuracy

from scipy.stats import randint

param_dist = {
    'num_layers': randint(1, 4),
    'num_heads': randint(2, 8),
    'd_model': [64, 128, 256],
    'd_ff': [256, 512, 1024],
    'epochs': [10, 20],  # Add epochs to the parameter grid if needed
    'batch_size': [32, 64]  # Add batch size options
}

from sklearn.model_selection import RandomizedSearchCV

# Create a KerasClassifierWrapper instance
model = KerasClassifierWrapper()

# Set up the random search
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                   n_iter=10, cv=3, verbose=2)

# Fit the random search
random_search_result = random_search.fit(X_train, y_train)

# %% [markdown]
# # 3.Evaluation

# %% [markdown]
# Define and train model in best parameters combination

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Embedding, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input
from tensorflow.keras.optimizers import Adam


#*****************************Creating model function************************#
def create_cnnmodel(optimizer='adam', filters=64, kernel_size=5, dropout_rate=0.5):
    sequence_length = 50  
    model = Sequential()
    model.add(Input(shape=(sequence_length,)))
    model.add(Embedding(input_dim=10000, output_dim=50))
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model
def create_lstm_model(optimizer='adam',output_dim=50 ,units=64,dropout_rate=0.5):
    model=Sequential()
    sequence_length=50
    model.add(Input(shape=(sequence_length,)))
    model.add(Embedding(input_dim=10000, output_dim=output_dim))
    model.add(LSTM(units=units))
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model
#Since the code of lstm is too long to put at here, We use previous code from above
#****************************************************************************#

#*********************Get models and do the training**************************#
best_cnn_e=create_cnnmodel('adam',32,3,0.2)
history1=best_cnn_e.fit(X_train,y_train,epochs=15, batch_size=128, validation_split=0.1)
best_lstm_e=create_lstm_model(optimizer='adam',output_dim=150,units=64,dropout_rate=0.3)
history2=best_lstm_e.fit(X_train,y_train,epochs=5,batch_size=64,validation_split=0.1)
best_transf_e=create_model(1,3,128,256)
history3=best_transf_e.fit(X_train,y_train,epochs=10,batch_size=32,validation_split=0.1)
#****************************************************************************#
# Out:
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.7158 - loss: 0.5397 - val_accuracy: 0.7729 - val_loss: 0.4779
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 22s 13ms/step - accuracy: 0.7967 - loss: 0.4391 - val_accuracy: 0.7744 - val_loss: 0.4730
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.8200 - loss: 0.3979 - val_accuracy: 0.7707 - val_loss: 0.4892
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.8414 - loss: 0.3573 - val_accuracy: 0.7672 - val_loss: 0.5093
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.8594 - loss: 0.3226 - val_accuracy: 0.7627 - val_loss: 0.5518
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.8782 - loss: 0.2853 - val_accuracy: 0.7549 - val_loss: 0.5873
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.8879 - loss: 0.2618 - val_accuracy: 0.7566 - val_loss: 0.6539
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.8959 - loss: 0.2437 - val_accuracy: 0.7534 - val_loss: 0.6905
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.9021 - loss: 0.2296 - val_accuracy: 0.7549 - val_loss: 0.7519
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9087 - loss: 0.2157 - val_accuracy: 0.7486 - val_loss: 0.8209
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.9121 - loss: 0.2057 - val_accuracy: 0.7460 - val_loss: 0.8347
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 22s 13ms/step - accuracy: 0.9158 - loss: 0.1976 - val_accuracy: 0.7455 - val_loss: 0.8736
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 22s 13ms/step - accuracy: 0.9199 - loss: 0.1899 - val_accuracy: 0.7476 - val_loss: 0.9273
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.9214 - loss: 0.1844 - val_accuracy: 0.7481 - val_loss: 0.9645
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.9243 - loss: 0.1775 - val_accuracy: 0.7452 - val_loss: 1.0289
# Epoch 1/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - accuracy: 0.7344 - loss: 0.5225 - val_accuracy: 0.7724 - val_loss: 0.4740
# Epoch 2/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 54s 16ms/step - accuracy: 0.7939 - loss: 0.4388 - val_accuracy: 0.7740 - val_loss: 0.4731
# Epoch 3/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 64s 19ms/step - accuracy: 0.8132 - loss: 0.4024 - val_accuracy: 0.7765 - val_loss: 0.4831
# Epoch 4/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 68s 20ms/step - accuracy: 0.8318 - loss: 0.3675 - val_accuracy: 0.7697 - val_loss: 0.5159
# Epoch 5/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 63s 19ms/step - accuracy: 0.8503 - loss: 0.3316 - val_accuracy: 0.7633 - val_loss: 0.5638
# Epoch 1/10
# /Users/liuyifan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'encoder_4', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 70s 10ms/step - accuracy: 0.6888 - loss: 0.5808 - val_accuracy: 0.7373 - val_loss: 0.5222
# Epoch 2/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 69s 10ms/step - accuracy: 0.7654 - loss: 0.4954 - val_accuracy: 0.7664 - val_loss: 0.5028
# Epoch 3/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 71s 10ms/step - accuracy: 0.7710 - loss: 0.4861 - val_accuracy: 0.7462 - val_loss: 0.5181
# Epoch 4/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 69s 10ms/step - accuracy: 0.7748 - loss: 0.4807 - val_accuracy: 0.7638 - val_loss: 0.5042
# Epoch 5/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 69s 10ms/step - accuracy: 0.7781 - loss: 0.4775 - val_accuracy: 0.7641 - val_loss: 0.5040
# Epoch 6/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 70s 10ms/step - accuracy: 0.7801 - loss: 0.4730 - val_accuracy: 0.7707 - val_loss: 0.5016
# Epoch 7/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 68s 10ms/step - accuracy: 0.7827 - loss: 0.4713 - val_accuracy: 0.7694 - val_loss: 0.5036
# Epoch 8/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 66s 10ms/step - accuracy: 0.7838 - loss: 0.4692 - val_accuracy: 0.7212 - val_loss: 0.5567
# Epoch 9/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 66s 10ms/step - accuracy: 0.7822 - loss: 0.4683 - val_accuracy: 0.7471 - val_loss: 0.5198
# Epoch 10/10
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 65s 10ms/step - accuracy: 0.7853 - loss: 0.4677 - val_accuracy: 0.7642 - val_loss: 0.5012

# %% [markdown]
# Evaluation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score


#*********************Define function for drawing loss descending curve******************#
def draw_loss_curve(history):
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
#****************************************************************************************#

#**********************Define function for drawing confusion matrix***********************#   
def draw_conf_matrix(y_pre_classes,y_test):
    
    conf_matrix = confusion_matrix(y_test, y_pre_classes)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()
#****************************************************************************************#

#*****************************Draw metrics bar plot***********************************#
def draw_bar(accuracy_l,precision_l,recall_l):
    model_names = ['CNN', 'LSTM', 'Transformer']
    bar_width = 0.2
    r1 = np.arange(len(model_names))  
    r2 = [x + bar_width for x in r1]  
    r3 = [x + bar_width for x in r2]  
    plt.figure(figsize=(8, 6))
    plt.bar(r1, accuracy_l, color='skyblue', width=bar_width, edgecolor='grey', label='Accuracy',alpha=0.8)
    plt.bar(r2, precision_l, color='lightcoral', width=bar_width, edgecolor='grey', label='Precision',alpha=0.8)
    plt.bar(r3, recall_l, color='palegreen', width=bar_width, edgecolor='grey', label='Recall',alpha=0.8)
    for i in range(len(r1)):
        plt.text(r1[i], accuracy_l[i] + 0.02, f'{accuracy_l[i]:.2f}', ha='center', va='bottom')
        plt.text(r2[i], precision_l[i] + 0.02, f'{precision_l[i]:.2f}', ha='center', va='bottom')
        plt.text(r3[i], recall_l[i] + 0.02, f'{recall_l[i]:.2f}', ha='center', va='bottom')
    plt.xlabel('Models', fontweight='bold')
    plt.xticks([r + bar_width for r in range(len(model_names))], model_names)  
    plt.title('Model Performance Comparison')
    plt.ylabel('Scores')
    plt.legend(fontsize=12, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
#***************************************************************************************#

#*******************************Function for evaluating**********************************#
def eva(model,history,X_test,y_test):
    # draw loss curve
    draw_loss_curve(history)
    # draw confusion matrix
    y_pre=model.predict(X_test)
    y_pre_classes = (y_pre> 0.5).astype("int32")
    draw_conf_matrix(y_pre_classes,y_test)
    accuracy_l.append(accuracy_score(y_test,y_pre_classes))
    precision_l.append(precision_score(y_test,y_pre_classes))
    recall_l.append(recall_score(y_test,y_pre_classes))
#****************************************************************************************#

if __name__=='__main__':
    accuracy_l=[]
    precision_l=[]
    recall_l=[]
    models=[[best_cnn_e,history1],[best_lstm_e,history2],[best_lstm_e,history3]]
    for model,history in models:
        eva(model,history,X_test,y_test)
    draw_bar(accuracy_l,precision_l,recall_l)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
